# %% [markdown]
# ##### REGRESION LINEAL SIMPLE

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.DataFrame()
df["Area"] = [2600,3000,3200,3600,4000]
df["Precio"] = [550000,565000,610000,68000,725000]

# %%
plt.scatter(df["Area"],
           df["Precio"])
